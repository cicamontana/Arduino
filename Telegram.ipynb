# %% [markdown]
# <a href="https://colab.research.google.com/github/cicamontana/Arduino/blob/master/Telegram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyTelegramBotAPI
# !pip install TeleBot
# !pip install aiogram
# !pip install SpeechRecognition
# !pip install pydub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.8/510.8 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 33.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 53.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.16.1
#     Uninstalling pydantic_core-2.16.1:
#       Successfully uninstalled pydantic_core-2.16.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.6.0
#     Uninstalling pydantic-2.6.0:
#       Successfully uninstalled pydantic-2.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# ...

# %%
import os
import telebot
import speech_recognition
from pydub import AudioSegment
from PIL import Image, ImageEnhance, ImageFilter


#image_path = '/content/drive/MyDrive/Python/20210212_122404(0).jpg'

import datetime
import pytz
from PIL import Image, ImageEnhance, ImageFilter


# Your bot token
bot_token = '6408586206:AAFFVDXyY55Ne6TZj3yIMdR8hY46DREdyC8'

bot = telebot.TeleBot(bot_token)
WAIT_TIME_SECONDS1 = 36

def transform_image(filename, filename1):
    # Функция обработки изображения
    source_image = Image.open(filename)
    enhanced_image = source_image.filter(ImageFilter.SHARPEN)
    enhanced_image = enhanced_image.convert('RGB')
    enhanced_image = enhanced_image.resize((8000, 1000))
    enhanced_image.save(filename1)
    return filename

@bot.message_handler(commands=['start'])
def send_chart( message):
    # Функция отправки обработанного изображения
   # file_id = message.photo[-1].file_id
    filename = '/content/drive/MyDrive/Python/plotPanel1_forest.png'
    filename1 = '/content/drive/MyDrive/Python/plotPanel_updated1.png'

    # Трансформируем изображение
    transform_image(filename, filename1)

    image = open(filename1, 'rb')
    bot.send_photo(message.chat.id, image)
    image.close()

    # Не забываем удалять ненужные изображения
    #if os.path.exists(filename):
    #    os.remove(filename)


bot.polling()

# %%
# !pip install PIL
# !pip install aiogram
# Out:
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.8/510.8 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 13.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.16.1
#     Uninstalling pydantic_core-2.16.1:
#       Successfully uninstalled pydantic_core-2.16.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.6.0
#     Uninstalling pydantic-2.6.0:
#       Successfully uninstalled pydantic-2.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# ...

# %%
# !pip install fastapi
# !pip install kaleido
# !pip install python-multipart
# !pip install uvicorn
# !pip install cohere
# !pip install OpenBinaryModeReading
# !pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 7.9 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.8 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ...
